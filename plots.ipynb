# %%
import scipy as sp
import matplotlib.pylab as plt
# %matplotlib inline

# %%
res = sp.stats.norm.rvs(1, 1, 1000)

# %%
plt.figure()
plt.title('Histogram N(1,1)')
plt.hist(res, bins=50)
plt.show()
